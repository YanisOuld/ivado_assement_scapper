# %% [markdown]
# # Museum Attendance vs City Population
#
# This notebook explores the relationship between:
# - annual museum attendance
# - city population
#
# Data sources:
# - Wikipedia: list of most visited museums
# - Kaggle: world cities population dataset
#
# All data processing is handled in the `src/` pipeline.
# This notebook focuses on exploration, visualization, and interpretation.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.max_columns", None)

# %%
museum_df = pd.read_csv("../data/raw/museums_raw.csv")
museum_df["annual_visitors"] = museum_df["annual_visitors"].astype(float)
museum_df
# Out:
#                                  museum_name                      city  \
# 0                                     Louvre                     Paris
# 1                   National Museum of China                   Beijing
# 2                            Vatican Museums        Vatican City, Rome
# 3                            Shenzhen Museum                  Shenzhen
# 4                             British Museum                    London
# 5        China Science and Technology Museum                   Beijing
# 6   Natural History Museum, South Kensington                    London
# 7                 Metropolitan Museum of Art             New York City
# 8                             Nanjing Museum                   Nanjing
# 9         American Museum of Natural History             New York City
# 10                               Tate Modern                    London
# 11                   Hubei Provincial Museum                     Wuhan
# 12                      Shanghai Museum East                  Shanghai
# 13                   National Gallery of Art          Washington, D.C.
# 14                  National Museum of Korea                     Seoul
# 15                             Musée d'Orsay                     Paris
# 16           National Museum of Anthropology               Mexico City
# 17                      State Russian Museum          Saint Petersburg
# 18                    State Hermitage Museum          Saint Petersburg
# 19                Victoria and Albert Museum  London, South Kensington
# 20                              Prado Museum                    Madrid
# 21                           Centre Pompidou                     Paris
# 22                          National Gallery                    London
# 23       Musée National d'Histoire Naturelle                     Paris
# 24          National Air and Space Museum[a]          Washington, D.C.
# 25                            Mevlana Museum                     Konya
# 26        National Museum of Natural History          Washington, D.C.
# 27                     Galleria degli Uffizi                  Florence
# 28        National Museum of Natural Science                  Taichung
# 29                     London Science Museum                    London
# 30                      Museum of Modern Art             New York City
# 31     National Museum of Nature and Science                     Tokyo
# 32                                        M+                 Hong Kong
# 33                   State Tretyakov Gallery                    Moscow
# 34                               Rijksmuseum                 Amsterdam
# 35                     Tokyo National Museum                     Tokyo
# 36                        Art Gallery of NSW                    Sydney
# 37               National Museum of Scotland                 Edinburgh
# 38                   Royal Museums Greenwich                    London
# 39                   Galleria dell'Accademia                  Florence
# 40    Smithsonian Museum of American History          Washington, D.C.
# 41                National Gallery Singapore                 Singapore
#
#     annual_visitors
# 0         9000000.0
# 1         6956800.0
# 2         6825436.0
# 3         6805000.0
# 4         6479952.0
# 5         6421000.0
# 6         6301972.0
# 7         5700000.0
# 8         5680000.0
# 9         5400000.0
# 10        4603025.0
# 11        4356943.0
# 12        4230000.0
# 13        3936543.0
# 14        3780000.0
# 15        3751000.0
# 16        3700000.0
# 17        3611899.0
# 18        3563590.0
# 19        3525700.0
# 20        3457057.0
# 21        3204369.0
# 22        3203451.0
# 23        3200000.0
# 24        3100000.0
# 25        3048000.0
# 26        3000000.0
# 27        2908828.0
# 28        2854455.0
# 29        2827242.0
# 30        2657377.0
# 31        2634997.0
# 32        2610000.0
# 33        2524450.0
# 34        2500000.0
# 35        2460000.0
# 36        2369339.0
# 37        2314974.0
# 38        2255753.0
# 39        2189103.0
# 40        2100000.0
# 41        2040481.0

# %%
plt.bar(museum_df["museum_name"], museum_df["annual_visitors"])
plt.xlabel("museum_name")
plt.ylabel("Number of visitor")
plt.title("Attendance of museum for each contry")
plt.show()

# %% [markdown]
# Next Step: Yanis

# %% [markdown]
# - Permettre de faire log ou pas log en cli
# - Comprendre le code
#     - Faire des modifictions si le besoin est la
#     - Enlever les commentaires inutiles
#     - Apprendre de ce code !
# - Remplir le notebook pour l'explication
# - Push le code et ne plus jamais le toucher
# - Envoyer ce code dans le email de Ivado labs !
#
# Apprentissage avant tout !
